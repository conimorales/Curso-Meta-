# %% [markdown]
# React no es un framework MVC.
# React es una biblioteca para construir interfaces de usuario componibles. Fomenta la creación de componentes de interfaz de usuario reutilizables que presentan datos que cambian con el tiempo.
#
# React no utiliza plantillas.
# React divide en encomponentes.
#
# Ventajas:
# - JavaScript es un lenguaje de programación flexible y potente con la capacidad de construir abstracciones. Esto es increíblemente importante en aplicaciones de gran tamaño.
# Al unificar su marcado con su lógica de vista correspondiente, React puede realmente hacer que las vistas sean más fáciles de ampliar y mantener.
#
# - Las actualizaciones de React son sencillas.
#
# En una aplicación JavaScript tradicional, tiene que mirar qué datos han cambiado y realizar imperativamente cambios en el DOM para mantenerlo actualizado. Incluso AngularJS, que proporciona una interfaz declarativa mediante directivas y vinculación de datos,
# requiere una función de vinculación para actualizar manualmente los nodos del DOM
# .
#
# React adopta un enfoque diferente.
#
# Cuando su componente se inicializa por primera vez, se llama al métodorender, que genera una representación ligera de su vista. A partir de esa representación, se produce una cadena de marcado y se inyecta en el documento. Cuando sus datos cambian, se llama de nuevo al métodorender. Para realizar las actualizaciones de la forma más eficiente posible, se difiere el valor de retorno de la llamada anterior arender con el nuevo y se genera un conjunto mínimo de cambios que se aplicarán al DOM.
#
# Los datos devueltos porrender no son ni una cadena ni un nodo DOM, sino una descripción ligera del aspecto que debería tener el DOM.
#
# Llamamos a este procesoreconciliación. Eche un vistazo a
# este jsFiddle
#  para ver un ejemplo de reconciliación en acción.
#
# Debido a que este re-renderizado es tan rápido (alrededor de 1ms para TodoMVC), el desarrollador no necesita especificar explícitamente los enlaces de datos. Hemos descubierto que este enfoque facilita la construcción de aplicaciones.
#
# HTML es sólo el principio.
# Debido a que React tiene su propia representación ligera del documento, podemos hacer algunas cosas bastante interesantes con él:
#
# Facebook tiene gráficos dinámicos que se renderizan en <canvas> en lugar de en HTML.
#
# Instagram es una aplicación web de "página única" construida enteramente con React y Backbone.Router. Los diseñadores contribuyen regularmente con código React con JSX.
#
# Hemos construido prototipos internos que ejecutan aplicaciones React en un web worker y utilizan React para impulsar vistas nativas de iOS a través de un puente Objective-C.
#
# Puede ejecutar React en el servidor para mejorar el SEO, el rendimiento, la compartición de código y la flexibilidad general.
#
# Los eventos se comportan de forma coherente y conforme a los estándares en todos los navegadores (incluido IE8) y utilizan automáticamente la delegación de eventos.
#
# Visite
# https://reactjs.org para
#  comprobar lo que hemos construido.

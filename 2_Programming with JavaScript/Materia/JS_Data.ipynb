# %% [markdown]
# JS interactividad
#
# // this is a comment!
# /*
# this is a multi-line comment
# */

# %% [markdown]
# Operadores
# - number
# - bigint
# - string
# - boolean
# - null
# - undefined

# %% [markdown]
# - Operador lógico AND:&&
# - Operador lógico OR:||
# - Operador lógico NOT:!
# - Operador de módulo:%
# - El operador de igualdad ==
# - El operador de igualdad estricta: ===
# - El operador de desigualdad: !=
# - El operador de desigualdad estricta: !==
# - Operador de asignación de suma:+=
# - El operador de asignación de concatenación:+=(es el mismo que el anterior - más adelante)
